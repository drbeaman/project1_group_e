# %% [markdown]
# # 2012 - 2016 Hate Crime Incidents by State Heatmap

# %% [markdown]
# Read in 2012, 2013, 2014, 2015 and 2016 Hate Crime Incidents by State from FBI, and create a heat map by US State.
# Incidents are normalized by population coverage of reporting agencies.

# %%
# Dependencies:
# First you need to pip install plotly and create free account online for 4the api key. 
# Second you need to pip install Orca.
# Then you can call plotly as py and orca as pio.
import pandas as pd
import numpy as np
import requests
import plotly
plotly.tools.set_credentials_file(username='drbeaman', api_key='sT7AGDihwOZJVDF5iwhl')
import plotly.plotly as py
import plotly.io as pio

# %%
# Import incidents by state file as DataFrame
incidents_2012 = "Resources/hate_crime_by_state_2012.csv"
incidents_2013 = "Resources/hate_crime_by_state_2013.csv"
incidents_2014 = "Resources/hate_crime_by_state_2014.csv"
incidents_2015 = "Resources/hate_crime_by_state_2015.csv"
incidents_2016 = "Resources/hate_crime_by_state_2016.csv"
incidents_2012_df = pd.read_csv(incidents_2012)
incidents_2013_df = pd.read_csv(incidents_2013)
incidents_2014_df = pd.read_csv(incidents_2014)
incidents_2015_df = pd.read_csv(incidents_2015)
incidents_2016_df = pd.read_csv(incidents_2016)

# %%
# Merge the data sets for two pairs at a time
combined_incidents_df_1516 = pd.merge(incidents_2015_df, incidents_2016_df, how='outer', \
    on='Participating state')
combined_incidents_df_1516.head()
# Out:
#   State code_x Participating state Number of\nparticipating\nagencies_x  \
# 0           AL             Alabama                                   34
# 1           AK              Alaska                                   33
# 2           AZ             Arizona                                  101
# 3           AR            Arkansas                                  279
# 4           CA          California                                  730
#
#   Population\ncovered_x  Agencies\nsubmitting\nincident\nreports_x  \
# 0             1,252,146                                          3
# 1               734,820                                          4
# 2             6,622,880                                         21
# 3             2,754,543                                          4
# 4            39,137,326                                        213
#
#    Total\nnumber of\nincidents\nreported_x  \
# 0                                       10
# ...

# %%
# Check the data types to see exact names of columns to rename
combined_incidents_df_1516.dtypes
# Out:
# State code_x                                  object
# Participating state                           object
# Number of\nparticipating\nagencies_x          object
# Population\ncovered_x                         object
# Agencies\nsubmitting\nincident\nreports_x      int64
# Total\nnumber of\nincidents\nreported_x        int64
# Incidents by Normalized Population_x         float64
# State code_y                                  object
# Number of\nparticipating\nagencies_y          object
# Population\ncovered_y                         object
# Agencies\nsubmitting\nincident\nreports_y      int64
# Total\nnumber of\nincidents\nreported_y        int64
# Incidents by Normalized Population_y         float64
# Unnamed: 7                                   float64
# Unnamed: 8                                    object
# dtype: object

# %%
# Drop unnecessary columns
condensed_1516= combined_incidents_df_1516.drop(columns=[
    'State code_y', \
    'Number of\nparticipating\nagencies_x', \
    'Agencies\nsubmitting\nincident\nreports_x',\
    'Number of\nparticipating\nagencies_y',\
    'Agencies\nsubmitting\nincident\nreports_y',
    'Unnamed: 7','Unnamed: 8'])
condensed_1516.head()
# Out:
#   State code_x Participating state Population\ncovered_x  \
# 0           AL             Alabama             1,252,146
# 1           AK              Alaska               734,820
# 2           AZ             Arizona             6,622,880
# 3           AR            Arkansas             2,754,543
# 4           CA          California            39,137,326
#
#    Total\nnumber of\nincidents\nreported_x  \
# 0                                       10
# 1                                        8
# 2                                      276
# 3                                        5
# 4                                      837
#
#    Incidents by Normalized Population_x Population\ncovered_y  \
# 0                              7.986289             1,013,839
# 1                             10.887020               738,566
# 2                             41.673713             6,361,910
# 3                              1.815183             2,853,645
# ...

# %%
#Rename columns
condensed_1516.rename(columns=
    {'State code_x':'State code','Population\ncovered_x':'2015 Population',\
     'Total\nnumber of\nincidents\nreported_x':'2015 Incidents',\
     'Incidents by Normalized Population_x':"2015 Incidents by Normalized Population",\
     'Population\ncovered_y':'2016 Population',\
     'Total\nnumber of\nincidents\nreported_y':'2016 Incidents',\
     'Incidents by Normalized Population_y':"2016 Incidents by Normalized Population"}, inplace=True)
condensed_1516.columns
# Out:
# Index(['State code', 'Participating state', '2015 Population',
#        '2015 Incidents', '2015 Incidents by Normalized Population',
#        '2016 Population', '2016 Incidents',
#        '2016 Incidents by Normalized Population'],
#       dtype='object')

# %%
# Preview DataFrame
condensed_1516.head()
# Out:
#   State code Participating state 2015 Population  2015 Incidents  \
# 0         AL             Alabama       1,252,146              10
# 1         AK              Alaska         734,820               8
# 2         AZ             Arizona       6,622,880             276
# 3         AR            Arkansas       2,754,543               5
# 4         CA          California      39,137,326             837
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839              14
# 1                                10.887020         738,566              11
# 2                                41.673713       6,361,910             213
# 3                                 1.815183       2,853,645              12
# 4                                21.386234      39,242,633             931
#
#    2016 Incidents by Normalized Population
# 0                                13.808899
# ...

# %%
# Merge 2014 data in
combined_incidents_df_1416 = pd.merge(condensed_1516, incidents_2014_df, how='outer', \
    on='Participating state')
combined_incidents_df_1416.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population State code_y  \
# ...

# %%
# Check the data types to see exact names of columns to rename
combined_incidents_df_1416.dtypes
# Out:
# State code_x                                object
# Participating state                         object
# 2015 Population                             object
# 2015 Incidents                             float64
# 2015 Incidents by Normalized Population    float64
# 2016 Population                             object
# 2016 Incidents                             float64
# 2016 Incidents by Normalized Population    float64
# State code_y                                object
# Number of\nparticipating\nagencies          object
# Population\ncovered                         object
# Agencies\nsubmitting\nincident\nreports    float64
# Total\nnumber of\nincidents\nreported      float64
# Incidents by Normalized Population         float64
# Unnamed: 7                                 float64
# Unnamed: 8                                 float64
# Unnamed: 9                                  object
# dtype: object

# %%
# Drop unnecessary columns
condensed_1416= combined_incidents_df_1416.drop(columns=[
    'State code_y', \
    'Number of\nparticipating\nagencies', \
    'Agencies\nsubmitting\nincident\nreports',\
    'Unnamed: 7','Unnamed: 8','Unnamed: 9'])
condensed_1416.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population Population\ncovered  \
# ...

# %%
#Rename columns
condensed_1416.rename(columns=
    {'State code_x':'State code',\
     'Population\ncovered':'2014 Population',\
     'Total\nnumber of\nincidents\nreported':'2014 Incidents',\
     'Incidents by Normalized Population':"2014 Incidents by Normalized Population"}, inplace=True)
condensed_1416.columns
# Out:
# Index(['State code', 'Participating state', '2015 Population',
#        '2015 Incidents', '2015 Incidents by Normalized Population',
#        '2016 Population', '2016 Incidents',
#        '2016 Incidents by Normalized Population', '2014 Population',
#        '2014 Incidents', '2014 Incidents by Normalized Population'],
#       dtype='object')

# %%
condensed_1416.head()
# Out:
#   State code Participating state 2015 Population  2015 Incidents  \
# 0         AL             Alabama       1,252,146            10.0
# 1         AK              Alaska         734,820             8.0
# 2         AZ             Arizona       6,622,880           276.0
# 3         AR            Arkansas       2,754,543             5.0
# 4         CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
# Merge 2013 data in
combined_incidents_df_1316 = pd.merge(condensed_1416, incidents_2013_df, how='outer', \
    on='Participating state')
combined_incidents_df_1316.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
# Check the data types to see exact names of columns to rename
combined_incidents_df_1316.dtypes
# Out:
# State code_x                                object
# Participating state                         object
# 2015 Population                             object
# 2015 Incidents                             float64
# 2015 Incidents by Normalized Population    float64
# 2016 Population                             object
# 2016 Incidents                             float64
# 2016 Incidents by Normalized Population    float64
# 2014 Population                             object
# 2014 Incidents                             float64
# 2014 Incidents by Normalized Population    float64
# State code_y                                object
# Number of\nparticipating\nagencies          object
# Population\ncovered                         object
# Agencies\nsubmitting\nincident\nreports    float64
# Total\nnumber of\nincidents\nreported      float64
# Incidents by Normalized Population         float64
# Unnamed: 7                                 float64
# ...

# %%
# Drop unnecessary columns
condensed_1316= combined_incidents_df_1316.drop(columns=[
    'State code_y', \
    'Number of\nparticipating\nagencies', \
    'Agencies\nsubmitting\nincident\nreports',\
    'Unnamed: 7','Unnamed: 8','Unnamed: 9'])
condensed_1316.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
#Rename columns
condensed_1316.rename(columns=
    {'State code_x':'State code',\
     'Population\ncovered':'2013 Population',\
     'Total\nnumber of\nincidents\nreported':'2013 Incidents',\
     'Incidents by Normalized Population':"2013 Incidents by Normalized Population"}, inplace=True)
condensed_1316.columns
# Out:
# Index(['State code', 'Participating state', '2015 Population',
#        '2015 Incidents', '2015 Incidents by Normalized Population',
#        '2016 Population', '2016 Incidents',
#        '2016 Incidents by Normalized Population', '2014 Population',
#        '2014 Incidents', '2014 Incidents by Normalized Population',
#        '2013 Population', '2013 Incidents',
#        '2013 Incidents by Normalized Population'],
#       dtype='object')

# %%
condensed_1316.head()
# Out:
#   State code Participating state 2015 Population  2015 Incidents  \
# 0         AL             Alabama       1,252,146            10.0
# 1         AK              Alaska         734,820             8.0
# 2         AZ             Arizona       6,622,880           276.0
# 3         AR            Arkansas       2,754,543             5.0
# 4         CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
# Merge 2012 data in
combined_incidents_df_1216 = pd.merge(condensed_1316, incidents_2012_df, how='outer', \
    on='Participating state')
combined_incidents_df_1216.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
# Check the data types to see exact names of columns to rename
combined_incidents_df_1216.dtypes
# Out:
# State code_x                                object
# Participating state                         object
# 2015 Population                             object
# 2015 Incidents                             float64
# 2015 Incidents by Normalized Population    float64
# 2016 Population                             object
# 2016 Incidents                             float64
# 2016 Incidents by Normalized Population    float64
# 2014 Population                             object
# 2014 Incidents                             float64
# 2014 Incidents by Normalized Population    float64
# 2013 Population                             object
# 2013 Incidents                             float64
# 2013 Incidents by Normalized Population    float64
# State code_y                                object
# Number of\nparticipating\nagencies          object
# Population\ncovered                         object
# Agencies\nsubmitting\nincident\nreports    float64
# ...

# %%
# Drop unnecessary columns
condensed_1216= combined_incidents_df_1216.drop(columns=[
    'State code_y', \
    'Number of\nparticipating\nagencies', \
    'Agencies\nsubmitting\nincident\nreports',\
    'Unnamed: 7','Unnamed: 8','Unnamed: 9'])
condensed_1216.head()
# Out:
#   State code_x Participating state 2015 Population  2015 Incidents  \
# 0           AL             Alabama       1,252,146            10.0
# 1           AK              Alaska         734,820             8.0
# 2           AZ             Arizona       6,622,880           276.0
# 3           AR            Arkansas       2,754,543             5.0
# 4           CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
#Rename columns
condensed_1216.rename(columns=
    {'State code_x':'State code',\
     'Population\ncovered':'2012 Population',\
     'Total\nnumber of\nincidents\nreported':'2012 Incidents',\
     'Incidents by Normalized Population':"2012 Incidents by Normalized Population"}, inplace=True)
condensed_1216.columns
# Out:
# Index(['State code', 'Participating state', '2015 Population',
#        '2015 Incidents', '2015 Incidents by Normalized Population',
#        '2016 Population', '2016 Incidents',
#        '2016 Incidents by Normalized Population', '2014 Population',
#        '2014 Incidents', '2014 Incidents by Normalized Population',
#        '2013 Population', '2013 Incidents',
#        '2013 Incidents by Normalized Population', '2012 Population',
#        '2012 Incidents', '2012 Incidents by Normalized Population'],
#       dtype='object')

# %%
condensed_1216.head()
# Out:
#   State code Participating state 2015 Population  2015 Incidents  \
# 0         AL             Alabama       1,252,146            10.0
# 1         AK              Alaska         734,820             8.0
# 2         AZ             Arizona       6,622,880           276.0
# 3         AR            Arkansas       2,754,543             5.0
# 4         CA          California      39,137,326           837.0
#
#    2015 Incidents by Normalized Population 2016 Population  2016 Incidents  \
# 0                                 7.986289       1,013,839            14.0
# 1                                10.887020         738,566            11.0
# 2                                41.673713       6,361,910           213.0
# 3                                 1.815183       2,853,645            12.0
# 4                                21.386234      39,242,633           931.0
#
#    2016 Incidents by Normalized Population 2014 Population  2014 Incidents  \
# ...

# %%
#Calculate Average Incident Rate by Normalized Population
condensed_1216['1216 Incident Avg by Normalized Population'] = \
    condensed_1216.loc[:,['2012 Incidents by Normalized Population','2013 Incidents by Normalized Population',\
    '2014 Incidents by Normalized Population','2015 Incidents by Normalized Population',\
    '2016 Incidents by Normalized Population']].mean(axis=1)

# %%
condensed_1216
# Out:
#    State code Participating state 2015 Population  2015 Incidents  \
# 0          AL             Alabama       1,252,146            10.0
# 1          AK              Alaska         734,820             8.0
# 2          AZ             Arizona       6,622,880           276.0
# 3          AR            Arkansas       2,754,543             5.0
# 4          CA          California      39,137,326           837.0
# 5          CO            Colorado       5,445,853           107.0
# 6          CT         Connecticut       3,399,068            93.0
# 7          DE            Delaware         945,934            11.0
# 8          FL             Florida       5,356,877            72.0
# 9          GA             Georgia       7,991,234            44.0
# 10         ID               Idaho       1,654,475            34.0
# 11         IL            Illinois      12,501,008            90.0
# 12         IN             Indiana       3,224,755            63.0
# ...

# %%
condensed = condensed_1216.dropna(how='all')
condensed
# Out:
#    State code Participating state 2015 Population  2015 Incidents  \
# 0          AL             Alabama       1,252,146            10.0
# 1          AK              Alaska         734,820             8.0
# 2          AZ             Arizona       6,622,880           276.0
# 3          AR            Arkansas       2,754,543             5.0
# 4          CA          California      39,137,326           837.0
# 5          CO            Colorado       5,445,853           107.0
# 6          CT         Connecticut       3,399,068            93.0
# 7          DE            Delaware         945,934            11.0
# 8          FL             Florida       5,356,877            72.0
# 9          GA             Georgia       7,991,234            44.0
# 10         ID               Idaho       1,654,475            34.0
# 11         IL            Illinois      12,501,008            90.0
# 12         IN             Indiana       3,224,755            63.0
# ...

# %% [markdown]
# # Map data

# %%
#For loop
for col in condensed.columns:
    condensed[col] = condensed[col].astype(str)

#Set color groups for heat scale 
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
    [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

# Prepare data to put into text.
# Text variable will be inserted into 'data' dictionary below.
# These columns will appear in plotly.com hover feature.
condensed['text'] = condensed['Participating state'] + '<br>' +\
    ' 2016 Population ' + condensed['2016 Population']+\
    ' 2016 Incidents '+ condensed['2016 Incidents']+\
    ' 1216 Incident Avg by Normalized Population '+condensed['1216 Incident Avg by Normalized Population']

# Set up data dictionary to hold the data
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = condensed['State code'],
        z = condensed['1216 Incident Avg by Normalized Population'].astype(float),
        locationmode = 'USA-states',
        text = condensed['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Incidents"
        )
    ) ]

# Set up layout dictionary for the visualization
layout = dict(
        title = '2012-2016 Avg Hate Crime Incidents by Participating State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

# Name the figure as a dictionary of the 1) data dictionary and 2) layout dictonary 
fig = dict( data=data, layout=layout )


#save fig
pio.write_image(fig, 'Images/1216_hc_incidents.png')

# Name the file for your inline viewing 
# url = py.iplot( fig, filename='d3-cloropleth-map' )
py.iplot(data, filename='d3-cloropleth-map')
# Out:
# C:\Users\dbeaman\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\dbeaman\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~drbeaman/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# ...
