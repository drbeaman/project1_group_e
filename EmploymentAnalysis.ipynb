# %%
import pandas as pd


source_file = 'Resources/employment/ACS_15_5YR_S2301/ACS_15_5YR_S2301_with_ann.csv'

# %%
data = pd.read_csv(source_file)

# %%
data.head(10)
# Out:
#         GEO.id GEO.id2     GEO.display-label  \
# 0           Id     Id2             Geography
# 1  0400000US01      01               Alabama
# 2  0400000US02      02                Alaska
# 3  0400000US04      04               Arizona
# 4  0400000US05      05              Arkansas
# 5  0400000US06      06            California
# 6  0400000US08      08              Colorado
# 7  0400000US09      09           Connecticut
# 8  0400000US10      10              Delaware
# 9  0400000US11      11  District of Columbia
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 16 years and over
# 1                                        3846845
# 2                                         565212
# 3                                        5207123
# 4                                        2328384
# 5                                       30312429
# 6                                        4168824
# 7                                        2906229
# ...

# %%
data=data[['GEO.display-label','HC02_EST_VC01']]

# %%
data
# Out:
#        GEO.display-label                                      HC02_EST_VC01
# 0              Geography  Labor Force Participation Rate; Estimate; Popu...
# 1                Alabama                                               58.3
# 2                 Alaska                                               70.6
# 3                Arizona                                               59.7
# 4               Arkansas                                               58.7
# 5             California                                               63.6
# 6               Colorado                                               68.4
# 7            Connecticut                                               67.5
# 8               Delaware                                               63.5
# 9   District of Columbia                                               69.0
# 10               Florida                                               59.2
# ...
